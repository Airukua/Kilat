# %%
import sys
from pathlib import Path

root = Path.cwd().resolve()
while root != root.parent and not (root / "pyproject.toml").exists():
    root = root.parent

sys.path.insert(0, str(root))
sys.modules.pop('data', None)

import data
from data.converter import parquet_to_memmap
from data.dataset import PretrainingDataset
import numpy as np

# %%
parquet_to_memmap(
    input_path="../data/tokens/train/tokens/tokenized.parquet", 
    output_path="../data/indo/train/tokens.npy",
    key_name="input_ids",      
    batch_size=10000,
    dtype=np.int32,
    force_overwrite=False,
    verbose=True,
)
# Out:
# Found 4 Parquet file(s).
# Counting total tokens (first pass)...
# Counting tokens: 0tok [00:00, ?tok/s]
# Total tokens: 696,592,384
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 parquet_to_memmap(
#       2     input_path="../data/tokens/train/tokens/tokenized.parquet",
#       3     output_path="../data/indo/train/tokens.npy",
#       4     key_name="input_ids",
#       5     batch_size=10000,
#       6     dtype=np.int32,
#       7     force_overwrite=False,
#       8     verbose=True,
#       9 )
#
# File ~/kilat/data/converter.py:257, in parquet_to_memmap(input_path, output_path, key_name, batch_size, dtype, force_overwrite, verbose)
#     234 # Step 2: Create memmap array (allocated but not filled)
#     235 # np.memmap with 'w+' mode creates a new binary file of the given size.
#     236 # We'll later flush and convert to .npy format? Actually np.save expects an array,
#    (...)    253 # The header is a Python dict with 'descr' and 'fortran_order', 'shape'.
#     254 # We'll write the header and then memory‑map the rest.
#     255 dtype_obj = np.dtype(dtype)
#     256 header = {
# --> 257     "descr": f"<{dtype.char}",  # little‑endian, e.g., '<i4'
#     258     "fortran_order": False,
#     259     "shape": (total_tokens,),
#     260 }
#     261 # Construct header bytes. numpy.lib.format.write_array_header_1_0 is private,
#     262 # but we can replicate it.
#     263 import numpy.lib.format as npyfmt
#
# AttributeError: type object 'numpy.int32' has no attribute 'char'

# %%
parquet_to_memmap(
    input_path="../data/tokens/validation/tokens/tokenized.parquet", 
    output_path="../data/indo/val/tokens.npy",
    key_name="input_ids",      
    batch_size=10000,
    dtype=np.int32,
    force_overwrite=False,
    verbose=True,
)
