# %%
import sys
from pathlib import Path
from kilat.pipeline.converter.to_memmap import parquet_to_memmap
import numpy as np

# %%
parquet_to_memmap(
    input_path="../data/fine-web-edu/train/data.parquet", 
    output_path="../data/fine-web/train/tokens.npy",
    key_name="input_ids",      
    batch_size=10000,
    dtype=np.int32,
    force_overwrite=False,
    verbose=True,
)
# Out:
# Found 1 Parquet file(s).
# Counting total tokens (first pass)...
# Counting tokens: 0tok [00:00, ?tok/s]
# Total tokens: 1,150,496,768
# Writing memmap:   0%|          | 0/1150496768 [00:00<?, ?tok/s]
# Memmap saved to ../data/fine-web/train/tokens.npy
# Metadata saved to ../data/fine-web/train/tokens.npy_meta.json

# %%
parquet_to_memmap(
    input_path="../data/fine-web-edu/val/data.parquet", 
    output_path="../data/fine-web/val/tokens.npy",
    key_name="input_ids",      
    batch_size=10000,
    dtype=np.int32,
    force_overwrite=False,
    verbose=True,
)
# Out:
# Found 1 Parquet file(s).
# Counting total tokens (first pass)...
# Counting tokens: 0tok [00:00, ?tok/s]
# Total tokens: 23,479,296
# Writing memmap:   0%|          | 0/23479296 [00:00<?, ?tok/s]
# Memmap saved to ../data/fine-web/val/tokens.npy
# Metadata saved to ../data/fine-web/val/tokens.npy_meta.json
