# %%
import sys
from pathlib import Path

root = Path.cwd().resolve()
while root != root.parent and not (root / "pyproject.toml").exists():
    root = root.parent

sys.path.insert(0, str(root))
sys.modules.pop('data', None)

import data
from data.converter import parquet_to_memmap
from data.dataset import PretrainingDataset
import numpy as np

# %%
parquet_to_memmap(
    input_path="../data/tokens/train/tokens/tokenized.parquet", 
    output_path="../data/indo/train/tokens.npy",
    key_name="input_ids",      
    batch_size=10000,
    dtype=np.int32,
    force_overwrite=False,
    verbose=True,
)
# Out:
# Found 4 Parquet file(s).
# Counting total tokens (first pass)...
# Counting tokens: 0tok [00:00, ?tok/s]
# Total tokens: 696,592,384
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 parquet_to_memmap(
#       2     input_path="../data/tokens/train/tokens/tokenized.parquet",  # this is a directory
#       3     output_path="../data/indo/train/tokens.npy",
#       4     key_name="input_ids",      # ← change to the correct column name
#       5     batch_size=10000,
#       6     dtype=np.int32,
#       7     force_overwrite=False,
#       8     verbose=True,
#       9 )
#
# File ~/kilat/data/converter.py:221, in parquet_to_memmap(input_path, output_path, key_name, batch_size, dtype, force_overwrite, verbose)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# AttributeError: type object 'numpy.int32' has no attribute 'char'
